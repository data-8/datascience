# %%
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
from tables import *
import numpy as np
from util import *

# %%
t = Table().with_column("a", np.array([1,2,3])).with_column("b", np.array([4,5,6])).with_column("c", np.array(["duck","duck","goose"]))
t = t.with_column("d", np.array([1, 20, 1000]))
t = t.with_row([4,7, "quail", 8])
t
# Out:
# a    | b    | c     | d
# 1    | 4    | duck  | 1
# 2    | 5    | duck  | 20
# 3    | 6    | goose | 1000
# 4    | 7    | quail | 8

# %%
t2 = t.drop("d")
t2
# Out:
# a    | b    | c
# 1    | 4    | duck
# 2    | 5    | duck
# 3    | 6    | goose
# 4    | 7    | quail

# %%
col1 = np.random.choice(1000, size = 20)
col2 = np.random.choice(1000, size = 20)
col3 = np.random.choice(1000, size = 20)
cats = make_array("a", "b", "b", "a","a", "b", "b", "c","a", "b", "e", "a","a", "d", "b", "a","c", "c", "b", "a")

rands = Table().with_column("First", col1).with_column("Second", col2).with_column("Third", col3).with_column("categories", cats)

# %%
rands.scatter("First", colors = "categories", sizes = "Third")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-a57d8be41100> in <module>()
# ----> 1 rands.scatter("First", colors = "categories", sizes = "Third")
#
# C:\Users\Erik Cheng\datascience\datascience\tables.py in scatter(self, column_for_x, select, overlay, fit_line, colors, labels, width, height, sizes, **vargs)
#    2220         x_label = self._as_label(column_for_x)
#    2221         y_labels = [i for i in y_labels if i!=colors and i != sizes]
# -> 2222         self._visualize(x_label, y_labels, None, overlay, draw, _vertical_x, width=width, height=height)
#    2223
#    2224     def _visualize(self, x_label, y_labels, ticks, overlay, draw, annotate, width=6, height=4):
#
# C:\Users\Erik Cheng\datascience\datascience\tables.py in _visualize(self, x_label, y_labels, ticks, overlay, draw, annotate, width, height)
#    2252                 axes=[axes]
#    2253             for axis, y_label, color in zip(axes, y_labels, colors):
# -> 2254                 draw(axis, y_label, color)
#    2255                 axis.set_ylabel(y_label, fontsize=16)
#    2256                 if x_label is not None:
#
# C:\Users\Erik Cheng\datascience\datascience\tables.py in draw(axis, label, color)
#    2211                 axis.plot([minx,maxx],[m*minx+b,m*maxx+b], color=color)
#    2212             if labels is not None:
# -> 2213                 for x, y, label in zip(x_data, y_data, self[labels]):
#    2214                     axis.annotate(label, (x, y),
#    2215                         xytext=(-20, 20),
#
# C:\Users\Erik Cheng\datascience\datascience\tables.py in __getitem__(self, index_or_label)
#     166
#     167     def __getitem__(self, index_or_label):
# --> 168         return self.column(index_or_label)
#     169
#     170     def __setitem__(self, index_or_label, values):
#
# C:\Users\Erik Cheng\datascience\datascience\tables.py in column(self, index_or_label)
#     284             )
#     285
# --> 286         return self._columns[self._as_label(index_or_label)]
#     287
#     288     @property
#
# C:\Users\Erik Cheng\datascience\datascience\tables.py in _as_label(self, index_or_label)
#    1300             return self.labels[index_or_label]
#    1301         else:
# -> 1302             raise ValueError(str(index_or_label) + ' is not a label or index')
#    1303
#    1304     def _as_labels(self, label_or_labels):
#
# ValueError: [(0.0, 0.102, 0.267), (1.0, 0.784, 0.0), (1.0, 0.0, 0.0), (0.702, 0.612, 0.302), (0.463, 0.537, 0.282)] is not a label or index
