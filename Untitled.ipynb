# %%
import numpy as np
from datascience import *
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
t = Table().with_columns(
    'Value', make_array(2, 3, 9),
    'Proportion', make_array(0.25, 0.5, 0.25)
)

t.hist(bin_column='Value', bins=np.arange(1.5, 9.6, 1))
# Out:
# OrderedDict([('Proporti', (array([2, 3, 9]), array([0.25, 0.5 , 0.25])))])

# %%
t = Table().with_columns(
    'Value', make_array(2, 3, 9),
    'Proportion count', make_array(0.25, 0.5, 0.25)
)

t.hist(bin_column='Value', bins=np.arange(1.5, 9.6, 1))
# Out:
# OrderedDict([('Proporti', (array([2, 3, 9]), array([0.25, 0.5 , 0.25])))])

# %%
score = Table().with_columns("scores", np.random.randn(100), "category", np.random.uniform(size=100) > 0.5, "scores2", np.random.randn(100))
score
# Out:
# scores     | category | scores2
# -0.575988  | True     | -0.0463811
# 0.803604   | False    | -0.168434
# 1.10973    | True     | 0.937435
# 0.322749   | False    | -0.549763
# -0.357573  | False    | -1.27591
# -1.12189   | True     | -2.04165
# 1.46775    | False    | -2.50801
# -0.0634734 | False    | -0.0784006
# -0.509234  | True     | 0.377616
# 2.1941     | True     | 0.969504
# ... (90 rows omitted)

# %%
score.hist('scores', group='category')
# Out:
# [('category=False', (array([ 8.03603551e-01,  3.22748880e-01, -3.57573206e-01,  1.46774799e+00,
#        -6.34734002e-02, -7.74208925e-01,  6.17202293e-01,  2.16552941e+00,
#         7.93117767e-01, -3.02472110e+00,  1.14887898e-01,  5.94421107e-01,
#         8.03301249e-01, -8.71814890e-01,  3.90494159e-01,  2.17873012e+00,
#        -9.28647037e-01, -8.78184976e-01,  1.75893847e+00,  1.36429772e+00,
#         1.20860036e+00, -1.17572489e+00, -4.16261611e-01, -2.25152191e-01,
#         7.84546451e-01,  2.68646962e-01,  7.20462164e-01, -4.98391700e-01,
#         4.45651215e-01, -3.09582639e-01, -1.82077973e+00,  4.94636624e-01,
#        -1.41181002e+00, -2.21846321e-02,  2.05178522e-03,  9.79710530e-02,
#         6.58386141e-01,  9.12873982e-01,  3.49660406e-01, -1.64141314e-01,
#         7.60017732e-01,  2.07392257e-01,  2.56402705e-01, -5.10872286e-01,
#        -6.94596415e-01]),)), ('category=True', (array([-0.57598838,  1.10973269, -1.12189161, -0.50923426,  2.19410105,
# ...

# %%
score.hist("scores")
# Out:
# OrderedDict([('scores', (array([-5.75988376e-01,  8.03603551e-01,  1.10973269e+00,  3.22748880e-01,
#        -3.57573206e-01, -1.12189161e+00,  1.46774799e+00, -6.34734002e-02,
#        -5.09234261e-01,  2.19410105e+00,  1.09124629e+00, -7.74208925e-01,
#         3.25210207e-01, -1.39233602e+00,  2.41417567e-01, -6.79233889e-01,
#        -1.35893272e+00,  6.17202293e-01,  2.16552941e+00, -3.94040830e-01,
#        -3.39071553e-01, -8.06219187e-01,  7.93117767e-01,  3.96933345e-01,
#        -9.25600461e-01, -3.02472110e+00, -1.04649375e+00,  1.14887898e-01,
#         5.94421107e-01, -7.87247138e-01,  8.03301249e-01, -8.71814890e-01,
#         8.07610340e-01,  3.90494159e-01, -5.28613158e-01, -1.01144189e-01,
#         2.17873012e+00, -6.66846465e-01, -9.62908314e-01, -9.28647037e-01,
#        -3.76354929e-01, -1.29663665e+00,  4.51017973e-01,  7.37159687e-01,
#        -8.78184976e-01,  5.97006368e-01,  1.75893847e+00, -1.36001620e+00,
# ...

# %%
score.hist()
# Out:
# OrderedDict([('scores', (array([-5.75988376e-01,  8.03603551e-01,  1.10973269e+00,  3.22748880e-01,
#        -3.57573206e-01, -1.12189161e+00,  1.46774799e+00, -6.34734002e-02,
#        -5.09234261e-01,  2.19410105e+00,  1.09124629e+00, -7.74208925e-01,
#         3.25210207e-01, -1.39233602e+00,  2.41417567e-01, -6.79233889e-01,
#        -1.35893272e+00,  6.17202293e-01,  2.16552941e+00, -3.94040830e-01,
#        -3.39071553e-01, -8.06219187e-01,  7.93117767e-01,  3.96933345e-01,
#        -9.25600461e-01, -3.02472110e+00, -1.04649375e+00,  1.14887898e-01,
#         5.94421107e-01, -7.87247138e-01,  8.03301249e-01, -8.71814890e-01,
#         8.07610340e-01,  3.90494159e-01, -5.28613158e-01, -1.01144189e-01,
#         2.17873012e+00, -6.66846465e-01, -9.62908314e-01, -9.28647037e-01,
#        -3.76354929e-01, -1.29663665e+00,  4.51017973e-01,  7.37159687e-01,
#        -8.78184976e-01,  5.97006368e-01,  1.75893847e+00, -1.36001620e+00,
# ...
