# %%
from datascience import *

# %% [markdown]
# # Drawing Simple Maps

# %% [markdown]
# Drawing a simple map by initializing a new Map object:

# %%
Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Adjusting the starting location and starting zoom of the map by passing in
# the following parameters:

# %%
Map(location=[37.78, -122.42]).show()
Map(location=[37.78, -122.42], zoom_start = 16).show()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Map(location=[37.78, -122.42], zoom_start = 16)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Adjusting the map's tile type:

# %%
Map(tiles='Stamen Toner').show()
Map(tiles='Stamen Terrain').show()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# All the above options can all be used together in combination in the Map
# object's initializer.

# %% [markdown]
# # Setting Markers on Maps

# %% [markdown]
# A simple marker can be added with the following syntax (note: the marker name pops up on-click):

# %%
Marker(30.27, -97.74, 'Austin')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The marker icon and color can be changed:

# %%
Marker(37.78, -122.42, 'San Francisco', color='red').show()
Marker(37.78, -122.42, 'San Francisco').format(marker_icon='thumbs-up', color="green").show()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Multiple markers can be set on a map:

# %%
features = [
    Marker(51.5135015, -0.1358392, 'A'), 
    Marker(51.5137, -0.1358392, 'B'), 
    Marker(51.5132, -0.138, 'C'), 
    Marker(51.5143, -0.135, 'D')
]
Map(features, zoom_start=17)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# More information/examples regarding adding multiple features to a `Map` can be found here. (#TODO: Adnan)

# %% [markdown]
# You can create multiple markers to place on a map on the fly:

# %%
points = [
    (51.5135015, -0.1358392), 
    (51.5137, -0.1358392), 
    (51.5132, -0.138), 
    (51.5143, -0.135),
]
lats, lons = zip(*points)
Marker.map(lats, lons, ['A', 'B', 'C', 'D'], color='red')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# More information/examples regarding `Marker.map` can be found here. (#TODO: Adnan)

# %% [markdown]
# Clustered maps are also possible. Passing in the `clustered_marker` argument as `True` will make the markers clustered.

# %%
# Read in the Alameda County Schools data
alameda_county_schools = Table.read_table('./alco_schools.csv')
alameda_county_schools.show(10)
Marker.map(alameda_county_schools['Y'],alameda_county_schools['X'], alameda_county_schools['Site'], 
           clustered_marker = True)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>X</th> <th>Y</th> <th>Site</th> <th>Address</th> <th>City</th> <th>State</th> <th>Type</th> <th>API</th> <th>Org</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>-122.239</td> <td>37.7448</td> <td>Amelia Earhart Elementary  </td> <td>400 Packet Landing Rd</td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>933 </td> <td>Public</td>
#         </tr>
#         <tr>
#             <td>-122.252</td> <td>37.739 </td> <td>Bay Farm Elementary        </td> <td>200 Aughinbaugh Way  </td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>932 </td> <td>Public</td>
#         </tr>
#         <tr>
#             <td>-122.259</td> <td>37.7621</td> <td>Donald D. Lum Elementary   </td> <td>1801 Sandcreek Way   </td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>853 </td> <td>Public</td>
#         </tr>
#         <tr>
#             <td>-122.235</td> <td>37.7653</td> <td>Edison Elementary          </td> <td>2700 Buena Vista Ave </td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>927 </td> <td>Public</td>
#         </tr>
#         <tr>
#             <td>-122.238</td> <td>37.754 </td> <td>Frank Otis Elementary      </td> <td>3010 Fillmore St     </td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>894 </td> <td>Public</td>
#         </tr>
#         <tr>
#             <td>-122.262</td> <td>37.7691</td> <td>Franklin Elementary        </td> <td>1433 San Antonio Ave </td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>893 </td> <td>Public</td>
#         </tr>
#         <tr>
#             <td>-122.251</td> <td>37.7695</td> <td>Henry Haight Elementary    </td> <td>2025 Santa Clara Ave </td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>821 </td> <td>Public</td>
#         </tr>
#         <tr>
#             <td>-122.286</td> <td>37.7819</td> <td>Ruby Bridges Elementary    </td> <td>351 Jack London Ave  </td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>802 </td> <td>Public</td>
#         </tr>
#         <tr>
#             <td>-122.272</td> <td>37.7724</td> <td>Washington Elementary      </td> <td>825 Taylor Ave       </td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>777 </td> <td>Public</td>
#         </tr>
#         <tr>
#             <td>-122.284</td> <td>37.7715</td> <td>William G. Paden Elementary</td> <td>444 Central Ave      </td> <td>Alameda</td> <td>CA   </td> <td>ES  </td> <td>844 </td> <td>Public</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (540 rows omitted)</p>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# A separate function, `Marker.map_table`, allows for data in a Table to be plotted with each row representing one `Marker`.

# %%
colors = ['red', 'blue', 'gray', 'green']
t = Table().with_columns(*zip(['lat', 'lon', 'name', 'color'], [lats, lons, colors, colors]))
t.show()
Marker.map_table(t)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>lat</th> <th>lon</th> <th>name</th> <th>color</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>51.5135</td> <td>-0.135839</td> <td>red  </td> <td>red  </td>
#         </tr>
#         <tr>
#             <td>51.5137</td> <td>-0.135839</td> <td>blue </td> <td>blue </td>
#         </tr>
#         <tr>
#             <td>51.5132</td> <td>-0.138   </td> <td>gray </td> <td>gray </td>
#         </tr>
#         <tr>
#             <td>51.5143</td> <td>-0.135   </td> <td>green</td> <td>green</td>
#         </tr>
#     </tbody>
# </table>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Setting Circles on Maps

# %% [markdown]
# Like `Marker`, a simple `Circle` can be placed on a map using the following syntax:

# %% [markdown]
# Clustered maps are also possible. Passing in the `clustered_marker` argument as `True` will make the markers clustered.

# %%
Circle(30.27, -97.74, 'Austin')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# `Circle` has more properties than `Marker`, however, such as: radius, line_color, fill_opacity, etc. A complete list of attributes that can be defined can be found here (https://leafletjs.com/reference-1.5.0.html#circlemarker)

# %%
Circle.map(lats, lons, colors=colors, fill_opacity=0.9, radius=20)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# More information/examples on `Circle.map` can be found here. (#TODO: Adnan)

# %% [markdown]
# Like `Marker`, `Circle.map_table`, allows for data in a Table to be plotted with each row representing one `Circle`.

# %%
# TODO: Add example with Circle.map_table

# %% [markdown]
# # Regions and Choropleths

# %% [markdown]
# You can render a collection of GeoJSON objects on a map and save the underlying GeoJSON objects for future usage. The `read_geojson` method reads in a file of GeoJSON geometries and returns a Map which acts as a dictionary of all the GeoJSON geometries in the file while rendering all the GeoJSON geometries when displayed.

# %%
states = Map.read_geojson('us-states.json')
states
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
states['CA']
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Map([states['CA'], states['NV'].format(color='yellow')])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The `read_geojson` method can also take in a URL which contains GeoJSON geometries.

# %%
url = "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/world-countries.json"
Map.read_geojson(url)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Choropleth maps can be made by creating a table that holds the data which will provide the map's shading. The table would map keys of the GeoJSON objects to a value.

# %%
unemployment = Table.read_table('us-unemployment.csv')
unemployment
# Out:
# State | Unemployment
# AL    | 7.1
# AK    | 6.8
# AZ    | 8.1
# AR    | 7.2
# CA    | 10.1
# CO    | 7.7
# CT    | 8.4
# DE    | 7.1
# FL    | 8.2
# GA    | 8.8
# ... (40 rows omitted)

# %% [markdown]
# That table can then be passed onto the `color` function which will generate the choropleth map.

# %%
states.color(unemployment)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
